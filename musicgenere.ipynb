# %%
import json
from google.colab import _message as _colab_message

# Get the current notebook's content
notebook_json = _colab_message.blocking_request('get_ipynb')

# Save the notebook content to the file 'musicgenere.ipynb' in the current directory
with open('musicgenere.ipynb', 'w') as f:
    json.dump(notebook_json['ipynb'], f)

# Add the new notebook file to git
# !git add musicgenere.ipynb

# Commit the changes
# !git commit -m "Add musicgenere.ipynb"

# Push the changes to the remote repository
# !git push https://${GITHUB_PAT}@github.com/hbaskar/testcolab.git

# %%
# !ls -la
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 Mar 20 03:07 .
# drwxr-xr-x 1 root root 4096 Mar 20 03:04 ..
# drwxr-xr-x 4 root root 4096 Mar 17 17:58 .config
# -rw-r--r-- 1 root root  957 Mar 20 03:07 musicgenere.ipynb
# drwxr-xr-x 1 root root 4096 Mar 17 17:58 sample_data

# %%
from getpass import getpass
token = getpass("Enter PAT: ")

# !git clone https://{token}@github.com/hbaskar/testcolab.git
# Out:
# Enter PAT: ··········
# Cloning into 'testcolab'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.

# %%
# %cd ./testcolab/
# Out:
# /content/testcolab

# %%
# !git config --global user.email "hari.baskar@yahoo.com"
# !git config --global user.name "hbaskar"
